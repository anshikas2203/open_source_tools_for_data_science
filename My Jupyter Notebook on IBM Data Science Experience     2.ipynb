# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Anshika**
#
# Student

# %% [markdown]
# *for me, data science is a way to become a detective. For every new case, i have to go into a new field to try to understand how it works, until i understand them, to try to acquire all the knowledge of the field without being a specialist. And because I am very curious about very different techniques in science, for me, it is exactly what I wanted.*

# %% [markdown]
# ### My code will add two numbers 5 and 3 in cell5 . The answer will be 8.

# %%
5+3
# Out:
# 8

# %% [markdown]
# ***
# ___
#
#
# * apple
# * mango
#
# ~~strikethrough~~
